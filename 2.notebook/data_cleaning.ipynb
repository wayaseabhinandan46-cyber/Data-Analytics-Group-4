# %% [markdown]
# ## Omnichannel Retail Sales and Inventory Analytics

# %%
# Import required libraries
import numpy as np 
import pandas as pd

# %%
# Load the dataset

raw_data = pd.read_csv('../1.data/retail_store_inventory.csv')
print(raw_data)
# Out:
#              Date Store ID Product ID Product Category Regions  \
# 0      01-01-2022     S001      P0001        Groceries   North
# 1      01-01-2022     S001      P0002             Toys   South
# 2      01-01-2022     S001      P0003             Toys    West
# 3      01-01-2022     S001      P0004             Toys   North
# 4      01-01-2022     S001      P0005      Electronics    East
# ...           ...      ...        ...              ...     ...
# 73095  01-01-2024     S005      P0016        Furniture    East
# 73096  01-01-2024     S005      P0017             Toys   North
# 73097  01-01-2024     S005      P0018         Clothing    West
# 73098  01-01-2024     S005      P0019             Toys    East
# 73099  01-01-2024     S005      P0020        Groceries    East
#
#        Inventory Level  Units Sold  Units Ordered  Demand Forecast  Price  \
# 0                  231         127             55           135.47  33.50
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Before starting the data cleaning process, it is important to understand the dataset structure, column names, data types, missing values, duplicate records, and overall dataset information. This initial exploration helps identify data quality issues and prepares the dataset for further preprocessing and analysis.

# %%
# Display the 1st 5 rows of the dataset
raw_data.head(5)
# Out:
#          Date Store ID Product ID Product Category Regions  Inventory Level  \
# 0  01-01-2022     S001      P0001        Groceries   North              231
# 1  01-01-2022     S001      P0002             Toys   South              204
# 2  01-01-2022     S001      P0003             Toys    West              102
# 3  01-01-2022     S001      P0004             Toys   North              469
# 4  01-01-2022     S001      P0005      Electronics    East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# ...

# %%
# Display the last 5 rows of the dataset
raw_data.tail(5)
# Out:
#              Date Store ID Product ID Product Category Regions  \
# 73095  01-01-2024     S005      P0016        Furniture    East
# 73096  01-01-2024     S005      P0017             Toys   North
# 73097  01-01-2024     S005      P0018         Clothing    West
# 73098  01-01-2024     S005      P0019             Toys    East
# 73099  01-01-2024     S005      P0020        Groceries    East
#
#        Inventory Level  Units Sold  Units Ordered  Demand Forecast  Price  \
# 73095               96           8            127            18.46  73.73
# 73096              313          51            101            48.43  82.57
# 73097              278          36            151            39.65  11.11
# 73098              374         264             21           270.52  53.14
# 73099              117           6            165             2.33  78.39
#
#        Discount Weather Condition  Holiday/Promotion  Competitor Pricing  \
# ...

# %%
# Display the shape of the dataset
raw_data.shape
# Out:
# (73100, 15)

# %%
raw_data.size
# Out:
# 1096500

# %%
# Display the data types of each column and check for null values
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73100 entries, 0 to 73099
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                73100 non-null  object
#  1   Store ID            73100 non-null  object
#  2   Product ID          73100 non-null  object
#  3   Product Category    73100 non-null  object
#  4   Regions             73100 non-null  object
#  5   Inventory Level     73100 non-null  int64
#  6   Units Sold          73100 non-null  int64
#  7   Units Ordered       73100 non-null  int64
#  8   Demand Forecast     73100 non-null  float64
#  9   Price               73100 non-null  float64
#  10  Discount            73100 non-null  int64
#  11  Weather Condition   73100 non-null  object
#  12  Holiday/Promotion   73100 non-null  int64
#  13  Competitor Pricing  73100 non-null  float64
#  14  Seasonality         73100 non-null  object
# ...

# %%
# Display the data types of each column
raw_data.dtypes
# Out:
# Date                   object
# Store ID               object
# Product ID             object
# Product Category       object
# Regions                object
# Inventory Level         int64
# Units Sold              int64
# Units Ordered           int64
# Demand Forecast       float64
# Price                 float64
# Discount                int64
# Weather Condition      object
# Holiday/Promotion       int64
# Competitor Pricing    float64
# Seasonality            object
# dtype: object

# %%
# Display the column names of the dataset
raw_data.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Product Category', 'Regions',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Demand Forecast',
#        'Price', 'Discount', 'Weather Condition', 'Holiday/Promotion',
#        'Competitor Pricing', 'Seasonality'],
#       dtype='object')

# %%
# Display summary statistics of the dataset
raw_data.describe()
# Out:
#        Inventory Level    Units Sold  Units Ordered  Demand Forecast  \
# count     73100.000000  73100.000000   73100.000000     73100.000000
# mean        274.469877    136.464870     110.004473       141.494720
# std         129.949514    108.919406      52.277448       109.254076
# min          50.000000      0.000000      20.000000        -9.990000
# 25%         162.000000     49.000000      65.000000        53.670000
# 50%         273.000000    107.000000     110.000000       113.015000
# 75%         387.000000    203.000000     155.000000       208.052500
# max         500.000000    499.000000     200.000000       518.550000
#
#               Price      Discount  Holiday/Promotion  Competitor Pricing
# count  73100.000000  73100.000000       73100.000000        73100.000000
# mean      55.135108     10.009508           0.497305           55.146077
# std       26.021945      7.083746           0.499996           26.191408
# ...

# %%
# Display the number of unique values for each column
raw_data.nunique()
# Out:
# Date                    731
# Store ID                  5
# Product ID               20
# Product Category          5
# Regions                   4
# Inventory Level         451
# Units Sold              498
# Units Ordered           181
# Demand Forecast       31608
# Price                  8999
# Discount                  5
# Weather Condition         4
# Holiday/Promotion         2
# Competitor Pricing     9751
# Seasonality               4
# dtype: int64

# %% [markdown]
# #### The Date column was read as object. Since the dataset uses day-month-year format, it was converted to datetime using dayfirst=True.

# %%
raw_data['Date'].head()
# Out:
# 0    01-01-2022
# 1    01-01-2022
# 2    01-01-2022
# 3    01-01-2022
# 4    01-01-2022
# Name: Date, dtype: object

# %%
raw_data['Date'] = pd.to_datetime(raw_data['Date'], dayfirst=True)

# %%
raw_data['Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### 1.Check null

# %%
raw_data.isnull()
# Out:
#         Date  Store ID  Product ID  Product Category  Regions  \
# 0      False     False       False             False    False
# 1      False     False       False             False    False
# 2      False     False       False             False    False
# 3      False     False       False             False    False
# 4      False     False       False             False    False
# ...      ...       ...         ...               ...      ...
# 73095  False     False       False             False    False
# 73096  False     False       False             False    False
# 73097  False     False       False             False    False
# 73098  False     False       False             False    False
# 73099  False     False       False             False    False
#
#        Inventory Level  Units Sold  Units Ordered  Demand Forecast  Price  \
# 0                False       False          False            False  False
# ...

# %%
raw_data.isnull().sum()
# Out:
# Date                  0
# Store ID              0
# Product ID            0
# Product Category      0
# Regions               0
# Inventory Level       0
# Units Sold            0
# Units Ordered         0
# Demand Forecast       0
# Price                 0
# Discount              0
# Weather Condition     0
# Holiday/Promotion     0
# Competitor Pricing    0
# Seasonality           0
# dtype: int64

# %%
# Drop rows with missing values
raw_data.dropna(inplace=True)

# %% [markdown]
# ### 2.Check duplicates

# %%
# Check for duplicate rows
raw_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73095    False
# 73096    False
# 73097    False
# 73098    False
# 73099    False
# Length: 73100, dtype: bool

# %%
raw_data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 3. Remove duplicates

# %%
# Drop duplicate rows
raw_data.drop_duplicates(inplace=True)

# %% [markdown]
# ### 4. Standardizing date/time formats

# %%
raw_data['Date'].head()
# Out:
# 0   2022-01-01
# 1   2022-01-01
# 2   2022-01-01
# 3   2022-01-01
# 4   2022-01-01
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# ### 5. Validating datatypes

# %%
raw_data.dtypes
# Out:
# Date                  datetime64[ns]
# Store ID                      object
# Product ID                    object
# Product Category              object
# Regions                       object
# Inventory Level                int64
# Units Sold                     int64
# Units Ordered                  int64
# Demand Forecast              float64
# Price                        float64
# Discount                       int64
# Weather Condition             object
# Holiday/Promotion              int64
# Competitor Pricing           float64
# Seasonality                   object
# dtype: object
